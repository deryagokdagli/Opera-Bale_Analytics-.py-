# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns_opera = ["Sezon yılı",
                 "Opera ve bale salonu",
                 "Koltuk sayısı",
                 "bos1",
                 "Toplam oynanan eser sayısı",
                 "Oynanan yerli eser",
                 "Oynanan yabancı eser",
                 "bos2",
                 "Toplam seyirci sayısı",
                 "Yerli eser seyirci sayısı",
                 "Yabancı eser seyirci sayısı"
                 ]
df_opera = pd.read_csv("opera.csv",skiprows=4,names=columns_opera)

# %%
df_opera.isnull().sum()
# Out:
# Sezon yılı                      0
# Opera ve bale salonu            4
# Koltuk sayısı                   4
# bos1                           29
# Toplam oynanan eser sayısı      4
# Oynanan yerli eser              4
# Oynanan yabancı eser            4
# bos2                           29
# Toplam seyirci sayısı           4
# Yerli eser seyirci sayısı       4
# Yabancı eser seyirci sayısı     4
# dtype: int64

# %%
df_opera.head()  # ilk 5 satır
# Out:
#   Sezon yılı  Opera ve bale salonu  Koltuk sayısı  bos1  \
# 0   1999/'00                   6.0         3474.0   NaN
# 1   2000/'01                   6.0         4391.0   NaN
# 2   2001/'02                   5.0         3897.0   NaN
# 3   2002/'03                   5.0         3850.0   NaN
# 4   2003/'04                   5.0         4264.0   NaN
#
#    Toplam oynanan eser sayısı  Oynanan yerli eser  Oynanan yabancı eser  bos2  \
# 0                        94.0                24.0                  70.0   NaN
# 1                        95.0                23.0                  72.0   NaN
# 2                        98.0                20.0                  78.0   NaN
# 3                       135.0                45.0                  90.0   NaN
# 4                       144.0                58.0                  86.0   NaN
#
#    Toplam seyirci sayısı  Yerli eser seyirci sayısı  \
# 0               258547.0                   110410.0
# 1               207360.0                    47839.0
# 2               165154.0                    18477.0
# 3               273271.0                   100054.0
# 4               457717.0                    31666.0
#
#    Yabancı eser seyirci sayısı
# 0                     148137.0
# 1                     159521.0
# 2                     146677.0
# 3                     173217.0
# 4                     426051.0

# %%
df_opera.tail()  # son 5 satır
# Out:
#                                            Sezon yılı  Opera ve bale salonu  \
# 24                                           2023/'24                  13.0
# 25   TÜİK, Sinema ve Gösteri Sanatları İstatistikleri                   NaN
# 26    TurkStat, Cinema and Performing Arts Statistics                   NaN
# 27  Kaynak: Kültür ve Turizm Bakanlığı, Devlet Ope...                   NaN
# 28  Source: Ministry of Culture and Tourism, Direc...                   NaN
#
#     Koltuk sayısı  bos1  Toplam oynanan eser sayısı  Oynanan yerli eser  \
# 24         8241.0   NaN                       209.0               111.0
# 25            NaN   NaN                         NaN                 NaN
# 26            NaN   NaN                         NaN                 NaN
# 27            NaN   NaN                         NaN                 NaN
# 28            NaN   NaN                         NaN                 NaN
#
#     Oynanan yabancı eser  bos2  Toplam seyirci sayısı  \
# 24                  98.0   NaN               438950.0
# 25                   NaN   NaN                    NaN
# 26                   NaN   NaN                    NaN
# 27                   NaN   NaN                    NaN
# 28                   NaN   NaN                    NaN
#
#     Yerli eser seyirci sayısı  Yabancı eser seyirci sayısı
# 24                   143172.0                     295778.0
# 25                        NaN                          NaN
# 26                        NaN                          NaN
# 27                        NaN                          NaN
# 28                        NaN                          NaN

# %%
df_opera
# Out:
#                                            Sezon yılı  Opera ve bale salonu  \
# 0                                            1999/'00                   6.0
# 1                                            2000/'01                   6.0
# 2                                            2001/'02                   5.0
# 3                                            2002/'03                   5.0
# 4                                            2003/'04                   5.0
# 5                                            2004/'05                   5.0
# 6                                            2005/'06                   5.0
# 7                                            2006/'07                   7.0
# 8                                            2007/'08                  10.0
# 9                                            2008/'09                   7.0
# 10                                           2009/'10                  12.0
# 11                                           2010/'11                   9.0
# 12                                           2011/'12                  14.0
# 13                                           2012/'13                  12.0
# 14                                           2013/'14                  15.0
# 15                                           2014/'15                  11.0
# 16                                           2015/'16                  11.0
# 17                                           2016/'17                  11.0
# 18                                           2017/'18                  11.0
# 19                                           2018/'19                  13.0
# 20                                           2019/'20                  13.0
# 21                                           2020/'21                  14.0
# 22                                           2021/'22                  14.0
# 23                                           2022/'23                  13.0
# 24                                           2023/'24                  13.0
# 25   TÜİK, Sinema ve Gösteri Sanatları İstatistikleri                   NaN
# 26    TurkStat, Cinema and Performing Arts Statistics                   NaN
# 27  Kaynak: Kültür ve Turizm Bakanlığı, Devlet Ope...                   NaN
# 28  Source: Ministry of Culture and Tourism, Direc...                   NaN
#
#     Koltuk sayısı  bos1  Toplam oynanan eser sayısı  Oynanan yerli eser  \
# 0          3474.0   NaN                        94.0                24.0
# 1          4391.0   NaN                        95.0                23.0
# 2          3897.0   NaN                        98.0                20.0
# 3          3850.0   NaN                       135.0                45.0
# 4          4264.0   NaN                       144.0                58.0
# 5          3850.0   NaN                       199.0                70.0
# 6          3860.0   NaN                       189.0                85.0
# 7          3834.0   NaN                        84.0                33.0
# 8          5879.0   NaN                       203.0               143.0
# 9          4345.0   NaN                       143.0                74.0
# 10         6967.0   NaN                       251.0               123.0
# 11         5077.0   NaN                       208.0                83.0
# 12         7799.0   NaN                       228.0                92.0
# 13         6776.0   NaN                       234.0               122.0
# 14        10288.0   NaN                       188.0                98.0
# 15         6398.0   NaN                       190.0                75.0
# 16         6398.0   NaN                       170.0               103.0
# 17         6398.0   NaN                       198.0               125.0
# 18         5970.0   NaN                       202.0                94.0
# 19        11672.0   NaN                       179.0                84.0
# 20        11672.0   NaN                       165.0                89.0
# 21         8949.0   NaN                        98.0                47.0
# 22         8925.0   NaN                       231.0               123.0
# 23         8260.0   NaN                       155.0                77.0
# 24         8241.0   NaN                       209.0               111.0
# 25            NaN   NaN                         NaN                 NaN
# 26            NaN   NaN                         NaN                 NaN
# 27            NaN   NaN                         NaN                 NaN
# 28            NaN   NaN                         NaN                 NaN
#
#     Oynanan yabancı eser  bos2  Toplam seyirci sayısı  \
# 0                   70.0   NaN               258547.0
# 1                   72.0   NaN               207360.0
# 2                   78.0   NaN               165154.0
# 3                   90.0   NaN               273271.0
# 4                   86.0   NaN               457717.0
# 5                  129.0   NaN               252076.0
# 6                  104.0   NaN               245448.0
# 7                   51.0   NaN               451271.0
# 8                   60.0   NaN               325364.0
# 9                   69.0   NaN               181605.0
# 10                 128.0   NaN               324007.0
# 11                 125.0   NaN               310623.0
# 12                 136.0   NaN               333707.0
# 13                 112.0   NaN               375223.0
# 14                  90.0   NaN               400420.0
# 15                 115.0   NaN               337007.0
# 16                  67.0   NaN               272578.0
# 17                  73.0   NaN               281069.0
# 18                 108.0   NaN               293002.0
# 19                  95.0   NaN               322189.0
# 20                  76.0   NaN               256063.0
# 21                  51.0   NaN                14032.0
# 22                 108.0   NaN               211233.0
# 23                  78.0   NaN               275086.0
# 24                  98.0   NaN               438950.0
# 25                   NaN   NaN                    NaN
# 26                   NaN   NaN                    NaN
# 27                   NaN   NaN                    NaN
# 28                   NaN   NaN                    NaN
#
#     Yerli eser seyirci sayısı  Yabancı eser seyirci sayısı
# 0                    110410.0                     148137.0
# 1                     47839.0                     159521.0
# 2                     18477.0                     146677.0
# 3                    100054.0                     173217.0
# 4                     31666.0                     426051.0
# 5                     76046.0                     176030.0
# 6                     89540.0                     155908.0
# 7                    121924.0                     329347.0
# 8                    120997.0                     204367.0
# 9                    105235.0                      76370.0
# 10                   113590.0                     210417.0
# 11                   128984.0                     181639.0
# 12                   169043.0                     164664.0
# 13                   220172.0                     155051.0
# 14                   185045.0                     215375.0
# 15                   143981.0                     193026.0
# 16                   153206.0                     119372.0
# 17                   115469.0                     165600.0
# 18                   119257.0                     173745.0
# 19                   146168.0                     176021.0
# 20                   121658.0                     134405.0
# 21                     6682.0                       7350.0
# 22                    83517.0                     127716.0
# 23                    98993.0                     176093.0
# 24                   143172.0                     295778.0
# 25                        NaN                          NaN
# 26                        NaN                          NaN
# 27                        NaN                          NaN
# 28                        NaN                          NaN

# %%
df_opera.dropna(thresh=2,inplace=True)
df_opera.dropna(axis=1,how="all",inplace=True)

# %%
df_opera
# Out:
#    Sezon yılı  Opera ve bale salonu  Koltuk sayısı  \
# 0    1999/'00                   6.0         3474.0
# 1    2000/'01                   6.0         4391.0
# 2    2001/'02                   5.0         3897.0
# 3    2002/'03                   5.0         3850.0
# 4    2003/'04                   5.0         4264.0
# 5    2004/'05                   5.0         3850.0
# 6    2005/'06                   5.0         3860.0
# 7    2006/'07                   7.0         3834.0
# 8    2007/'08                  10.0         5879.0
# 9    2008/'09                   7.0         4345.0
# 10   2009/'10                  12.0         6967.0
# 11   2010/'11                   9.0         5077.0
# 12   2011/'12                  14.0         7799.0
# 13   2012/'13                  12.0         6776.0
# 14   2013/'14                  15.0        10288.0
# 15   2014/'15                  11.0         6398.0
# 16   2015/'16                  11.0         6398.0
# 17   2016/'17                  11.0         6398.0
# 18   2017/'18                  11.0         5970.0
# 19   2018/'19                  13.0        11672.0
# 20   2019/'20                  13.0        11672.0
# 21   2020/'21                  14.0         8949.0
# 22   2021/'22                  14.0         8925.0
# 23   2022/'23                  13.0         8260.0
# 24   2023/'24                  13.0         8241.0
#
#     Toplam oynanan eser sayısı  Oynanan yerli eser  Oynanan yabancı eser  \
# 0                         94.0                24.0                  70.0
# 1                         95.0                23.0                  72.0
# 2                         98.0                20.0                  78.0
# 3                        135.0                45.0                  90.0
# 4                        144.0                58.0                  86.0
# 5                        199.0                70.0                 129.0
# 6                        189.0                85.0                 104.0
# 7                         84.0                33.0                  51.0
# 8                        203.0               143.0                  60.0
# 9                        143.0                74.0                  69.0
# 10                       251.0               123.0                 128.0
# 11                       208.0                83.0                 125.0
# 12                       228.0                92.0                 136.0
# 13                       234.0               122.0                 112.0
# 14                       188.0                98.0                  90.0
# 15                       190.0                75.0                 115.0
# 16                       170.0               103.0                  67.0
# 17                       198.0               125.0                  73.0
# 18                       202.0                94.0                 108.0
# 19                       179.0                84.0                  95.0
# 20                       165.0                89.0                  76.0
# 21                        98.0                47.0                  51.0
# 22                       231.0               123.0                 108.0
# 23                       155.0                77.0                  78.0
# 24                       209.0               111.0                  98.0
#
#     Toplam seyirci sayısı  Yerli eser seyirci sayısı  \
# 0                258547.0                   110410.0
# 1                207360.0                    47839.0
# 2                165154.0                    18477.0
# 3                273271.0                   100054.0
# 4                457717.0                    31666.0
# 5                252076.0                    76046.0
# 6                245448.0                    89540.0
# 7                451271.0                   121924.0
# 8                325364.0                   120997.0
# 9                181605.0                   105235.0
# 10               324007.0                   113590.0
# 11               310623.0                   128984.0
# 12               333707.0                   169043.0
# 13               375223.0                   220172.0
# 14               400420.0                   185045.0
# 15               337007.0                   143981.0
# 16               272578.0                   153206.0
# 17               281069.0                   115469.0
# 18               293002.0                   119257.0
# 19               322189.0                   146168.0
# 20               256063.0                   121658.0
# 21                14032.0                     6682.0
# 22               211233.0                    83517.0
# 23               275086.0                    98993.0
# 24               438950.0                   143172.0
#
#     Yabancı eser seyirci sayısı
# 0                      148137.0
# 1                      159521.0
# 2                      146677.0
# 3                      173217.0
# 4                      426051.0
# 5                      176030.0
# 6                      155908.0
# 7                      329347.0
# 8                      204367.0
# 9                       76370.0
# 10                     210417.0
# 11                     181639.0
# 12                     164664.0
# 13                     155051.0
# 14                     215375.0
# 15                     193026.0
# 16                     119372.0
# 17                     165600.0
# 18                     173745.0
# 19                     176021.0
# 20                     134405.0
# 21                       7350.0
# 22                     127716.0
# 23                     176093.0
# 24                     295778.0

# %%
df_opera.describe()
# Out:
#        Opera ve bale salonu  Koltuk sayısı  Toplam oynanan eser sayısı  \
# count             25.000000      25.000000                   25.000000
# mean               9.880000    6457.360000                  171.600000
# std                3.515679    2488.807912                   48.986393
# min                5.000000    3474.000000                   84.000000
# 25%                6.000000    4264.000000                  143.000000
# 50%               11.000000    6398.000000                  188.000000
# 75%               13.000000    8241.000000                  203.000000
# max               15.000000   11672.000000                  251.000000
#
#        Oynanan yerli eser  Oynanan yabancı eser  Toplam seyirci sayısı  \
# count           25.000000             25.000000              25.000000
# mean            80.840000             90.760000          290520.080000
# std             34.692314             24.797984           97199.826039
# min             20.000000             51.000000           14032.000000
# 25%             58.000000             72.000000          252076.000000
# 50%             84.000000             90.000000          281069.000000
# 75%            103.000000            108.000000          333707.000000
# max            143.000000            136.000000          457717.000000
#
#        Yerli eser seyirci sayısı  Yabancı eser seyirci sayısı
# count                  25.000000                    25.000000
# mean               110845.000000                179675.080000
# std                 49633.148356                 79725.619115
# min                  6682.000000                  7350.000000
# 25%                 89540.000000                148137.000000
# 50%                115469.000000                173217.000000
# 75%                143172.000000                193026.000000
# max                220172.000000                426051.000000

# %%
x = df_opera["Sezon yılı"]
y_yerli = df_opera["Yerli eser seyirci sayısı"]
y_yabanci = df_opera["Yabancı eser seyirci sayısı"]

plt.figure(figsize=(12,6),dpi=200)

plt.plot(x, y_yerli, marker="o", color="#3E87AB", label="Yerli Eser Seyirci")
plt.plot(x, y_yabanci, marker="s", color="#FF7F50", label="Yabancı Eser Seyirci")

plt.title("Opera & Bale: Sezonlara Göre Seyirci Trendleri (2000–2024)", fontsize=14)
plt.xlabel("Sezon yılı", fontsize=12)
plt.ylabel("Seyirci Sayısı", fontsize=12)
plt.xticks(rotation=45)  # X eksenini döndürmek için
plt.grid(alpha=0.2)
plt.legend()

# Grafiği göster
plt.tight_layout()
plt.show()

# %%
x = df_opera["Sezon yılı"]
y_oynananyerli = df_opera["Oynanan yerli eser"]
y_oynananyabanci = df_opera["Oynanan yabancı eser"]
plt.figure(figsize=(12,6),dpi=200)

plt.plot(x, y_oynananyerli, label="Oynanan yerli eser", marker="o", color="#F4D35E")
plt.plot(x, y_oynananyabanci, label="Oynanan yabancı eser", marker="s", color="#4361EE")
plt.title("Opera & Bale: Oynanan Yerli ve Yabancı Eser Sayılarının Dağılımı")
plt.xlabel("Sezon yılı",fontsize=12)
plt.ylabel("Yerli & Yabancı Eser",fontsize=12)
plt.xticks(rotation=45)
plt.grid(alpha=0.2)
plt.legend()

plt.tight_layout()
plt.show()

# %%
x_yerliesersayisi = df_opera["Oynanan yerli eser"]
y_yerlieserizleyici = df_opera["Yerli eser seyirci sayısı"]

plt.figure(figsize=(12,6),dpi=200)

plt.scatter(x_yerliesersayisi, y_yerlieserizleyici, marker="o", label="Oynanan yerli eser")

plt.xlabel("Yerli Eser Sayısı")
plt.ylabel("Yerli Eser Seyirci Sayısı")
plt.title("Opera & Bale: Yerli Eser Sayısı vs Seyirci Sayısı")
plt.legend()
plt.tight_layout()
plt.show()

# %%
x_yabanciesersayisi = df_opera["Oynanan yabancı eser"]
y_yabancieserizleyici = df_opera["Yabancı eser seyirci sayısı"]

plt.figure(figsize=(12,6),dpi=200)

plt.scatter(x_yabanciesersayisi, y_yabancieserizleyici, marker="s", label="Oynanan yabancı eser")
plt.xlabel("Yabancı Eser Sayısı")
plt.ylabel("Yabancı Eser Seyirci Sayısı")
plt.title("Opera & Bale: Yabancı Eser Sayısı vs Seyirci Sayısı")
plt.legend()
plt.tight_layout()
plt.show()

# %%
r = df_opera["Oynanan yabancı eser"].corr(df_opera["Yabancı eser seyirci sayısı"])

# %%
r
# Out:
# np.float64(0.10013436400865178)

# %%
s = df_opera["Oynanan yerli eser"].corr(df_opera["Yerli eser seyirci sayısı"])

# %%
s
# Out:
# np.float64(0.560010110262561)

# %%
x_koltuk = df_opera["Koltuk sayısı"]
y_yerli = df_opera["Yerli eser seyirci sayısı"]
y_yabanci = df_opera["Yabancı eser seyirci sayısı"]

plt.figure(figsize=(12,6),dpi=200)

plt.scatter(x_koltuk, y_yerli, color="#636EFA", marker="o", label="Yerli Eser Seyirci", s=100,alpha=0.8)
plt.scatter(x_koltuk, y_yabanci, color="#EF553B", marker="s", label="Yabancı Eser Seyirci", s=100,alpha=0.8)

plt.title("Opera & Bale: Yerli-Yabancı Eser Seyirci ve Koltuk Dağılımı (2000–2024)", fontsize=14)
plt.xlabel("Koltuk sayısı", fontsize=12)
plt.ylabel("Seyirci Sayısı", fontsize=12)
plt.grid(alpha=0.2)
plt.legend()
plt.tight_layout()
plt.show()

# %%
t1 = df_opera["Koltuk sayısı"].corr(df_opera["Yerli eser seyirci sayısı"])
t2 = df_opera["Koltuk sayısı"].corr(df_opera["Yabancı eser seyirci sayısı"])

# %%
t1
# Out:
# np.float64(0.3397814451256246)

# %%
t2
# Out:
# np.float64(-0.18996703490521147)
